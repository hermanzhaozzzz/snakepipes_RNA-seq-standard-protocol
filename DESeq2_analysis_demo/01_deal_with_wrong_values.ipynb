# %%
import pandas as pd

# %%
df = pd.read_csv("exp_v1.txt", sep = "\t", header = 0, index_col=0, na_values=0, low_memory='False')

# %%
df
# Out:
#          GSM425929 GSM425930 GSM425931 GSM425932 GSM425933 GSM425934  \
# Symbol
# A1BG            3         4         5         5         5         4
# A1BG-AS1        5         5         3         3         3         5
# A1CF            5         4         4         4         4         4
# A2M             7         8         8         6         7         7
# A2M-AS1         6         6         7         6         6         6
# ...            ...       ...       ...       ...       ...       ...
# ZYG11A          4         1         3         3          2        3
# ZYG11B          7         7         8         7          7        7
# ZYX             6         7         6         6          6        6
# ZZEF1           6         6         6         6          6        6
# ZZZ3            7         7         7         8          7        8
#
#          GSM425935 GSM425936 GSM425937 GSM425938  ... GSM425919 GSM425920  \
# Symbol                                            ...
# ...

# %%
def my_int(x):
    try:
        return int(x)
    except:
        return 0
df = df.applymap(my_int)

# %%
df.to_csv('exp_v2.csv')
